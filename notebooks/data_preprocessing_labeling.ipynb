# %% [markdown]
# # Data processing and labeling

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
import os
sys.path.append('/content/gdrive/MyDrive')
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Processing

# %%
import pandas as pd
# df = pd.read_csv('/content/gdrive/MyDrive/telegram_data.csv')
df = pd.read_csv('../data/telegram_data.csv')
# Set display options to show full text
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
# df = pd.read_csv('/content/gdrive/MyDrive/clean_data.csv')
dfc = pd.read_csv('../final_tokens_labels.csv')

# %%
def txt_to_conll(txt_file, conll_file):
    with open(txt_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    with open(conll_file, 'w', encoding='utf-8') as f:
        for line in lines:
            # Assuming each line contains a sentence
            tokens = line.strip().split()  # Tokenize by whitespace
            
            # Example: Assign labels (customize this as necessary)
            # For demonstration, we're labeling all tokens as 'O'
            # Replace this logic with your actual label assignment
            for token in tokens:
                # Write each token with its label
                f.write(f"{token} O\n")  # Change 'O' to your actual label if needed
            
            # Add a blank line to separate sentences
            f.write("\n")

# Usage
txt_file = '../labeled_telegram_product_price_location.txt'  # Path to your input TXT file
conll_file = '../labeled_zemen_express.conll'  # Path to save your CoNLL file
txt_to_conll(txt_file, conll_file)

# %%
df.head(2)
# Out:
#     Channel Title Channel Username    ID  \
# 0  Zemen Express®    @ZemenExpress  5334
# 1  Zemen Express®    @ZemenExpress  5333
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Message  \
# 0  💥💥...................................💥💥\n\n🎯Korean Body Scrub Sponge \n\n     👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ\n\nዋጋ፦  💲🏷  200 ብር ✅\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 1    💥💥...................................💥💥\n\n🎯Korean Body Scrub Sponge \n     👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ\n\nዋጋ፦  💲🏷  200 ብር ✅\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
#
#                         Date Media Path
# 0  2024-09-26 10:04:28+00:00        NaN
# 1  2024-09-26 10:04:14+00:00        NaN

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 956

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (4044, 6)

# %%
df = pd.read

# %% [markdown]
# - check the text

# %%
text1 = df['Message'].iloc[8]
# print(text1)

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import re
def preprocess_text(text):

    text = re.sub(r'[^\w\s,]', '', text) # Remove emojis
    text = re.sub(r'\.{2,}', '', text) # Remove multiple dots
    text = re.sub(r'\s+', ' ', text).strip() # Remove extra spaces
    text = re.sub(r'\b[a-zA-Z]+\b', '', text) # Remove English words
    # text = re.sub(r'\b\d{10,}\b', '', text) # Remove phone numbers

    # Step 1: Identify and label prices
    def label_prices(text):
        # Find prices with the pattern like '200 ብር'
        prices = re.findall(r'\d+\s*ብር', text)
        # Replace identified prices with a label 'PRICE'
        for price in prices:
            text = text.replace(price, 'PRICE')
        return text,prices
    text_with_labeled_prices,prices = label_prices(text)

    # Step 2: Remove other numbers while keeping prices intact
    cleaned_text = re.sub(r'\b(?!PRICE\b)\d+\b', '', text_with_labeled_prices)
    # cleaned_text = re.sub(r'\b\S*\d+\S*\b', '', cleaned_text)  # Remove alphanumerics like 'S05/S06'

    # Step 3: Remove 'PRICE' label back to the original price format
    # cleaned_text = re.sub(r'\b\d+\b(?!\s*ብር)', '', text_with_labeled_prices)

    # Clean up extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()

    # Replace the 'PRICE' label back to the original price format
    for price in prices:
        cleaned_text = cleaned_text.replace('PRICE', price)

    # Step 1: Text Cleaning
    cleaned_text = re.sub(r'[A-Za-z]', '', cleaned_text)  # Remove English letters
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)  # Remove punctuation
    cleaned_text = re.sub(r'\b(ቁ1|ቁ2)', '', cleaned_text) # Removing ቁ1 and ቁ2 from locations
    cleaned_text = cleaned_text.replace('_', ' ') # Replacing underscore with space
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()  # Remove extra spaces
    cleaned_text = cleaned_text.replace('0506', '') # Convert to lowercase text.replace('0506', '')
    # Step 2: Tokenization
    tokens = word_tokenize(cleaned_text)

    # Remove unwanted characters (keeping Amharic characters)
    # text = re.sub(r'[^አ-ፈ0-9\s]', '', text)  # Keep only Amharic characters and numbers
    return cleaned_text

# %%
preprocess_text(text1)
# cleaned_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 preprocess_text(text1)
#       2 # cleaned_text
#
# Cell In[10], line 42, in preprocess_text(text)
#      40 cleaned_text = cleaned_text.replace('0506', '') # Convert to lowercase text.replace('0506', '')
#      41 # Step 2: Tokenization
# ---> 42 tokens = word_tokenize(cleaned_text)
#      44 # Remove unwanted characters (keeping Amharic characters)
#      45 # text = re.sub(r'[^አ-ፈ0-9\s]', '', text)  # Keep only Amharic characters and numbers
#      46 return cleaned_text
#
# NameError: name 'word_tokenize' is not defined

# %%
len(tokens)
# Out:
# 61

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([' '.join(tokens)])
X.toarray()
X
# Out:
# <1x54 sparse matrix of type '<class 'numpy.float64'>'
# 	with 54 stored elements in Compressed Sparse Row format>

# %%
dft = df.copy()

# %%
dft['cleaned_message'] = dft['Message'].apply(preprocess_text)

# %%
dft.head
# Out:
#     Channel Title Channel Username    ID  \
# 0  Zemen Express®    @ZemenExpress  5334
# 1  Zemen Express®    @ZemenExpress  5333
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Message  \
# 0  💥💥...................................💥💥\n\n🎯Korean Body Scrub Sponge \n\n     👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ\n\nዋጋ፦  💲🏷  200 ብር ✅\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 1    💥💥...................................💥💥\n\n🎯Korean Body Scrub Sponge \n     👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ\n\nዋጋ፦  💲🏷  200 ብር ✅\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
#
#                         Date Media Path  \
# 0  2024-09-26 10:04:28+00:00        NaN
# 1  2024-09-26 10:04:14+00:00        NaN
#
#                                                                                                                                                                        cleaned_message
# 0  የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ ዋጋ 200 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 1  የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ ዋጋ 200 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን

# %% [markdown]
# ###Labeling

# %% [markdown]
# - better so far

# %%
import re

def label_message_utf8_with_birr(message):
    # # Split the message at the first occurrence of '\n'
    # if '\n' in message:
    #     first_line, remaining_message = message.split('\n', 1)
    # else:
    #     first_line, remaining_message = message, ""

    labeled_tokens = []
    location_listB = [ 'ፒያሳ',  'መገናኛ']
    location_listI = ['መሰረት', 'ደፋር', 'ሞል', 'ጊዮርጊስ', 'አደባባይ', 'ራመት', 'ታቦር', 'ኦዳ', 'ህንፃ','ደራርቱ', 'ህንፃ']

    # # Tokenize the first line
    # first_line_tokens = re.findall(r'\S+', first_line)

    # # Label the first token as B-PRODUCT and the rest as I-PRODUCT
    # if first_line_tokens:
    #     labeled_tokens.append(f"{first_line_tokens[0]} B-PRODUCT")  # First token as B-PRODUCT
    #     for token in first_line_tokens[1:]:
    #         labeled_tokens.append(f"{token} I-PRODUCT")  # Remaining tokens as I-PRODUCT

    # Process the remaining message normally
    if message:
        lines = message.split('\n')
        for line in lines:
            tokens = re.findall(r'\S+', line)  # Tokenize each line while considering non-ASCII characters

            for token in tokens:
                # Check if token is a price (e.g., 500 ETB, $100, or ብር)
                if re.match(r'^\d{10,}$', token):
                    labeled_tokens.append(f"{token} O")  # Label as O for "other" or outside of any entity
                elif 'ዋጋ' in token:
                    labeled_tokens.append(f"{token} B-PRICE")
                # elif re.match(r'^\d+(\.\d{1,2})?$', token) and 'ብር' in token or 'ETB' in token or '$' in token or 'ብር' in token:
                #     labeled_tokens.append(f"{token} I-PRICE")
                # elif re.search(r'\b(ዋጋ|ብር)\b', token):
                #     # Extract the numeric part if it's a valid price
                #     price_match = re.search(r'(?<!\d)(0|[1-9]\d*)(\.\d{1,2})?', token)
                #     if price_match:
                #         labeled_tokens.append(f"{price_match.group()} I-PRICE")  # Label the price
                #         # numbers_only.append(price_match.group())  # Store the number only
                # Check if token could be a location (e.g., cities or general location names)
                elif re.match(r'^\d+(\.\d{1,2})?$', token) or 'ብር' in token:
                    labeled_tokens.append(f"{token} I-PRICE")
                elif re.match(r'^\d+(\.\d{1,2})?\s*ብር$', token):
                    labeled_tokens.append(f"{token} I-PRICE")
                elif 'ብር' in token:
                    labeled_tokens.append(f"{token} I-PRICE")
                elif any(loc in token for loc in location_listB):
                    labeled_tokens.append(f"{token} B-LOC")
                elif any(loc in token for loc in location_listI):
                    labeled_tokens.append(f"{token} I-LOC")
                # Assume other tokens are part of a product name or general text
                else:
                    labeled_tokens.append(f"{token} O")

    return "\n".join(labeled_tokens)

# %%
# Apply the updated function to the non-null messages
dft['Labeled_Message'] = dft['cleaned_message'].apply(label_message_utf8_with_birr)

# %%
dft.tail(5)
# Out:
#        Channel Title Channel Username   ID  \
# 4994  Zemen Express®    @ZemenExpress  121
# 4995  Zemen Express®    @ZemenExpress  120
# 4996  Zemen Express®    @ZemenExpress  115
# 4997  Zemen Express®    @ZemenExpress  114
# 4998  Zemen Express®    @ZemenExpress  113
#
#                                                                                                                                                                                                                                                                                                                                Message  \
# 4994  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌክትሪክ ሃይል በሚሞላ ) ዉሃ መሳቢያ \n                     በተመጣጣኝ ዋጋ \n▹▸ በ USB ቻርጅ የሚሰራ\n▹▸ አንድ ጊዜ ቻርጅ 5 ጋሎን ውሀ የሚስብ\n▹▸ አውቶማቲክ መክፈቻና መዝጊያ ያለው\n▹▸ ለአጠቃቀም ቀላል\n    \n 🚚🚚🚚   ያሉበት ድረስ በነፃ እናደርሳለን  🚛🚛🚛🚛\n\nዋጋ 500 ብር \nhttps://telegram.me/ZemenExpress\n\n📱+251928460606 , +251902660722 ይደውሉ
# 4995  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌክትሪክ ሃይል በሚሞላ ) ዉሃ መሳቢያ \n                     በተመጣጣኝ ዋጋ \n▹▸ በ USB ቻርጅ የሚሰራ\n▹▸ አንድ ጊዜ ቻርጅ 5 ጋሎን ውሀ የሚስብ\n▹▸ አውቶማቲክ መክፈቻና መዝጊያ ያለው\n▹▸ ለአጠቃቀም ቀላል\n    \n 🚚🚚🚚   ያሉበት ድረስ በነፃ እናደርሳለን  🚛🚛🚛🚛\n\nዋጋ 500 ብር \nhttps://telegram.me/ZemenExpress\n\n📱+251928460606 , +251902660722 ይደውሉ
# 4996                                                                                     #ZemenExpress® is a platform that connect suppliers,  retailers, dealers & buyers at the same time for better shoping experience.\nFeedback፡ @zemenCallCenter\n📌NEW PRODUCTS📌NEW DEALS.   ❗️FREE DELIVERY❗️\n📲 +251928460606 or +251902660722
# 4997                                                                                                                                                                                                                                                                                                  https://telegram.me/ZemenExpress
# 4998                                                                                        #ZemenExpress® is a platform that connect suppliers,  retailers, dealers & buyers at the same time for better shoping experience.\nFeedback፡ @zemenexpress\n📌NEW PRODUCTS📌NEW DEALS.   ❗️FREE DELIVERY❗️\n📲 +251928460606 or +251902660722
#
#                            Date                    Media Path  \
# 4994  2020-04-24 16:52:40+00:00                           NaN
# 4995  2020-04-24 16:15:34+00:00  photos\@ZemenExpress_120.jpg
# 4996  2020-04-24 09:32:43+00:00                           NaN
# 4997  2020-04-24 04:38:51+00:00                           NaN
# 4998  2020-04-23 17:58:01+00:00                           NaN
#
#                                                                                                                                                                   cleaned_message  \
# 4994  ከውኃ ማሰሮ ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና በኤሌክትሪክ ሃይል በሚሞላ ዉሃ መሳቢያ በተመጣጣኝ ዋጋ በ ቻርጅ የሚሰራ አንድ ጊዜ ቻርጅ ጋሎን ውሀ የሚስብ አውቶማቲክ መክፈቻና መዝጊያ ያለው ለአጠቃቀም ቀላል ያሉበት ድረስ በነፃ እናደርሳለን ዋጋ 500 ብር ይደውሉ
# 4995  ከውኃ ማሰሮ ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና በኤሌክትሪክ ሃይል በሚሞላ ዉሃ መሳቢያ በተመጣጣኝ ዋጋ በ ቻርጅ የሚሰራ አንድ ጊዜ ቻርጅ ጋሎን ውሀ የሚስብ አውቶማቲክ መክፈቻና መዝጊያ ያለው ለአጠቃቀም ቀላል ያሉበት ድረስ በነፃ እናደርሳለን ዋጋ 500 ብር ይደውሉ
# 4996
# 4997
# 4998
#
#                                                                                                                                                                                                                                                                                                                  Labeled_Message
# 4994  ከውኃ O\nማሰሮ O\nላይ O\nየመጠጥ O\nዉሃ O\nየሚስብ O\nተንቀሳቃሽ O\nእና O\nበኤሌክትሪክ O\nሃይል O\nበሚሞላ O\nዉሃ O\nመሳቢያ O\nበተመጣጣኝ O\nዋጋ B-PRICE\nዋጋ O\nበ O\nቻርጅ O\nየሚሰራ O\nአንድ O\nጊዜ O\nቻርጅ O\nጋሎን O\nውሀ O\nየሚስብ O\nአውቶማቲክ O\nመክፈቻና O\nመዝጊያ O\nያለው O\nለአጠቃቀም O\nቀላል O\nያሉበት O\nድረስ O\nበነፃ O\nእናደርሳለን O\nዋጋ B-PRICE\nዋጋ O\n500 O\nብር I-PRICE\nይደውሉ O
# 4995  ከውኃ O\nማሰሮ O\nላይ O\nየመጠጥ O\nዉሃ O\nየሚስብ O\nተንቀሳቃሽ O\nእና O\nበኤሌክትሪክ O\nሃይል O\nበሚሞላ O\nዉሃ O\nመሳቢያ O\nበተመጣጣኝ O\nዋጋ B-PRICE\nዋጋ O\nበ O\nቻርጅ O\nየሚሰራ O\nአንድ O\nጊዜ O\nቻርጅ O\nጋሎን O\nውሀ O\nየሚስብ O\nአውቶማቲክ O\nመክፈቻና O\nመዝጊያ O\nያለው O\nለአጠቃቀም O\nቀላል O\nያሉበት O\nድረስ O\nበነፃ O\nእናደርሳለን O\nዋጋ B-PRICE\nዋጋ O\n500 O\nብር I-PRICE\nይደውሉ O
# 4996
# 4997
# 4998

# %%
# Display the updated DataFrame
dft[['cleaned_message', 'Labeled_Message']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                cleaned_message  \
# 0                                                                                                                                                                          የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ ዋጋ 200 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 1                                                                                                                                                                          የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ ዋጋ 200 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 2                                                                                                                                                      ከብረት የተሰራ ጫማ እና የተለያዩ ዕቃወች ማስቀመጫ ለመገጣጠም ቀላል ባለ ስድስት መደርደሪያ ያለው ዋጋ 2250 ብር አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 3  ዘመናዊ የልብስ ማስቀመጫ ቁምሳጥን በቀላሉ የሚገጣጠም የሚነቃቀል ከቦታ ወደ ቦታ ለማንቀሳቀስ የሚመች ቀላል ክብደት ያለው ባለ ዚፕ የሸራ ልብስ ያለው ፍሬሞቹ የብረት ቱቦዎች የሆኑ መገጣጠሚያዎቹ ጠንካራ ካርቦኔትድ ፕላስቲኮች የሆኑ ለቤትዎ ውበት የሚሠጥ ቦታ የማይዝ ሲሆን ቁመት ሳሜ የጎን ስፋት ሳሜ ወርድ ሳሜ ዋጋ 3500 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 8                                                                                                                                                                                                        ዋጋ 150 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Labeled_Message
# 0                                                                                                                                                                                                                                                                                      የሞተ O\nቆዳን O\nእንዲሁም O\nቆሻሻን O\nለማፅዳት O\nተመራጭ O\nዋጋ B-PRICE\n200 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 1                                                                                                                                                                                                                                                                                      የሞተ O\nቆዳን O\nእንዲሁም O\nቆሻሻን O\nለማፅዳት O\nተመራጭ O\nዋጋ B-PRICE\n200 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 2                                                                                                                                                                                                                                                         ከብረት O\nየተሰራ O\nጫማ O\nእና O\nየተለያዩ O\nዕቃወች O\nማስቀመጫ O\nለመገጣጠም O\nቀላል O\nባለ O\nስድስት O\nመደርደሪያ O\nያለው O\nዋጋ B-PRICE\n2250 I-PRICE\nብር I-PRICE\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 3  ዘመናዊ O\nየልብስ O\nማስቀመጫ O\nቁምሳጥን O\nበቀላሉ O\nየሚገጣጠም O\nየሚነቃቀል O\nከቦታ O\nወደ O\nቦታ O\nለማንቀሳቀስ O\nየሚመች O\nቀላል O\nክብደት O\nያለው O\nባለ O\nዚፕ O\nየሸራ O\nልብስ O\nያለው O\nፍሬሞቹ O\nየብረት O\nቱቦዎች O\nየሆኑ O\nመገጣጠሚያዎቹ O\nጠንካራ O\nካርቦኔትድ O\nፕላስቲኮች O\nየሆኑ O\nለቤትዎ O\nውበት O\nየሚሠጥ O\nቦታ O\nየማይዝ O\nሲሆን O\nቁመት O\nሳሜ O\nየጎን O\nስፋት O\nሳሜ O\nወርድ O\nሳሜ O\nዋጋ B-PRICE\n3500 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 8                                                                                                                                                                                                                                                                                                                                      ዋጋ B-PRICE\n150 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O

# %%
# Check for entries that contain any numbers
has_numbers = dft['cleaned_message'].str.contains(r'\d', na=False)

# Count unique entries that contain numbers
unique_number_count = has_numbers.sum()
print("Count of unique entries with numbers in cleaned_message:", unique_number_count)
# Out:
# Count of unique entries with numbers in cleaned_message: 3785

# %%
# Select the specific row and column
row_index = 681  # For example, the second row
selected_column = 'cleaned_message'

# Get the text from the selected cell
text = dft.loc[row_index, selected_column]

# Count numbers using regex
numbers = re.findall(r'\d+', text)  # Find all occurrences of numbers
number_count = len(numbers)  # Count how many numbers are found

print(f"Text in selected row and column: {text}")
print(f"Number of numbers present: {number_count}")
# Out:
# Text in selected row and column: ዋጋ ርዝመት 160 500 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# Number of numbers present: 4

# %%
dft.loc[681:700, ['Message', 'cleaned_message', 'Labeled_Message']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Message  \
# 681  💥💥...................................💥💥\n\n📌 Long Sewer Cleaning Wire Spring\n\n👍Bringing more convenience to the people in their daily life.\n\nQuality iron wire and pp material\n👍Flexible spring cable and retractable claws\n👍Long enough to get deep into drains\n👍Remove any clogs and debris\n👍For kitchen, bathroom, sinks, drain, tubs, etc.\n\n\n         ዋጋ፦  ርዝመት 160Cm 💲🏷 500 ብር \n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 682  💥💥...................................💥💥\n\n📌 Long Sewer Cleaning Wire Spring\n\n👍Bringing more convenience to the people in their daily life.\n\nQuality iron wire and pp material\n👍Flexible spring cable and retractable claws\n👍Long enough to get deep into drains\n👍Remove any clogs and debris\n👍For kitchen, bathroom, sinks, drain, tubs, etc.\n\n\n         ዋጋ፦  ርዝመት 160Cm 💲🏷 500 ብር \n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 683                                                                                                                                                                                                                                                                              💥💥...................................💥💥\n\n📌 Sonifer® Toaster \n\n👍 2 slice cool touch Toaster \n👍 700 watt\n\nዋጋ፦  💲🏷  2500ብር\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 684                                                                                                                                                                                                                                                                              💥💥...................................💥💥\n\n📌 Sonifer® Toaster \n\n👍 2 slice cool touch Toaster \n👍 700 watt\n\nዋጋ፦  💲🏷  2500ብር\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 685                                                                                                                                                                                                                                                                              💥💥...................................💥💥\n\n📌 Sonifer® Toaster \n\n👍 2 slice cool touch Toaster \n👍 700 watt\n\nዋጋ፦  💲🏷  2500ብር\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 686                                                                                                                                                                                                                                                                                                         💥💥...................................💥💥\n\n🎯Kids Baby toilet trainer\n\nዋጋ፦  💲🏷  2000 ብር\n\n♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 687                                                                                                                                                              💥💥...................................💥💥\n\n📌Saachi Hot plate\n\n#ትልቁ ሳቺ ባለሁለት ምድጃ ስቶቭ\n\n👍 2000 ዋት\n👍 ፊውዝ የተገጠመለት\n👍 ትልቅ ድስት መሸከም የሚችል\n👍 አስተማማኝ ቴርሞስታት\n👍 ባለ ፊውዝ\n\nዋጋ፦  💵🏷   ትልቁ ➡️2700 ብር\n                       ትንሹ ➡️ 2400 ብር \n\n♦️ውስን ፍሬ ነው ያለው🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 693                                                                                                                                                                                                                        💥💥...................................💥💥\n\n📌950ml Glass tea pot with filter + 100ml 4pcs tea cup\n\n👍 የሚጣድ ሙቀት የሚቋቋም \n👍የራሱ ማጣሪያ ወንፊት ያለው \n👍4 100ml የመያዝ አቅም ያላቸው መጠጫወች ጋር\n\n ዋጋ፦  💵🏷  1600 ብር\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 694                                                                                                  💥💥...................................💥💥\n\n👔🩳የልብስ ማስጫ (ማድረቂያ)👗🥻 \n\n🎯Three Layers of clothes hanger \n\n👍 3double layer \n👍 780*620*1650 mm\n👍  እስከ 30kg መሸከም ሚችል \n👍 ማጠፍ መዘርጋት ሚቻል \n👍 ቦታ ቆጣቢ ,ለcondominuinm.... \n👍 ልብስን ሳይገረጣ በፍጥነት የሚያደርቅ \n👍በቤት ውስጥም ሆነ ከቤት ውጭ ልብሶችን ለማድረቅ እና ለመስቀል ተስማሚ የሆነ\n\n ዋጋ፦  💵🏷  3400 ብር\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 695                                                                                                        💥💥...................................💥💥\n\n👔🩳የልብስ ማስጫ (ማድረቂያ)👗🥻 \n\n🎯Three Layers of clothes hanger \n\n👍 3double layer \n👍 780*620*1650 mm\n👍  እስከ 40kg መሸከም ሚችል \n👍 ማጠፍ መዘርጋት ሚቻል \n👍 ቦታ ቆጣቢ ,ለcondominuinm.... \n👍 ልብስን በፍጥነት የሚያደርቅ \n👍በቤት ውስጥም ሆነ ከቤት ውጭ ልብሶችን ለማድረቅ እና ለመስቀል ተስማሚ የሆነ\n\n ዋጋ፦  💵🏷  3400 ብር\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 696                                                                                                                                                                                                                                                                                                                    💥💥...................................💥💥\n\n📌 Replacement Silicon Nipple \n\n  👍የጡት ጫፍ\n\nዋጋ፦  💲🏷  400 ብር\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
# 697                                                                                                                                                                                         💥💥...................................💥💥\n\n📌 Sonifer® Electric Steam Iron\n\n💯💯💯 Original  ልብስ መተኮሻ\n\n👍2200W ⚠️\n\n👍ልብስ የማያቃጥል ceramic  plate\n\n👍 በእፏሎት የሚሰራ 🌧\n\n👍ለሁሉም የጨርቅ አይነቶች የሚሆን\n\nዋጋ፦  💵🏷  2500 ብር\n\n♦️ውስን ፍሬ ነው ያለው🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\n\n📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606\n\n➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥
#
#                                                                                                                                                                                                                                                                cleaned_message  \
# 681                                                                                                             ዋጋ ርዝመት 160 500 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 682                                                                                                             ዋጋ ርዝመት 160 500 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 683                                                                                                                           ዋጋ 2500ብር ውስን ፍሬ ነው ያለው መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 684                                                                                                                           ዋጋ 2500ብር ውስን ፍሬ ነው ያለው መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 685                                                                                                                           ዋጋ 2500ብር ውስን ፍሬ ነው ያለው መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 686                                                                                                                     ዋጋ 2000 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 687                          ትልቁ ሳቺ ባለሁለት ምድጃ ስቶቭ ዋት ፊውዝ የተገጠመለት ትልቅ ድስት መሸከም የሚችል አስተማማኝ ቴርሞስታት ባለ ፊውዝ ዋጋ ትልቁ 2700 ብር ትንሹ 2700 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 693                                                             950 100 4 የሚጣድ ሙቀት የሚቋቋም የራሱ ማጣሪያ ወንፊት ያለው 100 የመያዝ አቅም ያላቸው መጠጫወች ጋር ዋጋ 1600 ብር አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 694  የልብስ ማስጫ ማድረቂያ 3 እስከ 30 መሸከም ሚችል ማጠፍ መዘርጋት ሚቻል ቦታ ቆጣቢ ለ ልብስን ሳይገረጣ በፍጥነት የሚያደርቅ በቤት ውስጥም ሆነ ከቤት ውጭ ልብሶችን ለማድረቅ እና ለመስቀል ተስማሚ የሆነ ዋጋ 3400 ብር አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 695        የልብስ ማስጫ ማድረቂያ 3 እስከ 40 መሸከም ሚችል ማጠፍ መዘርጋት ሚቻል ቦታ ቆጣቢ ለ ልብስን በፍጥነት የሚያደርቅ በቤት ውስጥም ሆነ ከቤት ውጭ ልብሶችን ለማድረቅ እና ለመስቀል ተስማሚ የሆነ ዋጋ 3400 ብር አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 696                                                                                                                             የጡት ጫፍ ዋጋ 400 ብር አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 697                                                            ልብስ መተኮሻ 2200 ልብስ የማያቃጥል በእፏሎት የሚሰራ ለሁሉም የጨርቅ አይነቶች የሚሆን ዋጋ 2500 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ  ፒያሳ ጊዮርጊስ አደባባይ ራመት ታቦር ኦዳ ህንፃ 1ኛ ፎቅ ሱቅ ቁ 1 ፒያሳ ቅርንጫፍ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Labeled_Message
# 681                                                                                                                                                                                        ዋጋ B-PRICE\nርዝመት O\n160 I-PRICE\n500 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 682                                                                                                                                                                                        ዋጋ B-PRICE\nርዝመት O\n160 I-PRICE\n500 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 683                                                                                                                                                                                                                              ዋጋ B-PRICE\n2500ብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 684                                                                                                                                                                                                                              ዋጋ B-PRICE\n2500ብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 685                                                                                                                                                                                                                              ዋጋ B-PRICE\n2500ብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 686                                                                                                                                                                                                            ዋጋ B-PRICE\n2000 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 687                                         ትልቁ O\nሳቺ O\nባለሁለት O\nምድጃ O\nስቶቭ O\nዋት O\nፊውዝ O\nየተገጠመለት O\nትልቅ O\nድስት O\nመሸከም O\nየሚችል O\nአስተማማኝ O\nቴርሞስታት O\nባለ O\nፊውዝ O\nዋጋ B-PRICE\nትልቁ O\n2700 I-PRICE\nብር I-PRICE\nትንሹ O\n2700 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 693                                                                                        950 I-PRICE\n100 I-PRICE\n4 I-PRICE\nየሚጣድ O\nሙቀት O\nየሚቋቋም O\nየራሱ O\nማጣሪያ O\nወንፊት O\nያለው O\n100 I-PRICE\nየመያዝ O\nአቅም O\nያላቸው O\nመጠጫወች O\nጋር O\nዋጋ B-PRICE\n1600 I-PRICE\nብር I-PRICE\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 694  የልብስ O\nማስጫ O\nማድረቂያ O\n3 I-PRICE\nእስከ O\n30 I-PRICE\nመሸከም O\nሚችል O\nማጠፍ O\nመዘርጋት O\nሚቻል O\nቦታ O\nቆጣቢ O\nለ O\nልብስን O\nሳይገረጣ O\nበፍጥነት O\nየሚያደርቅ O\nበቤት O\nውስጥም O\nሆነ O\nከቤት O\nውጭ O\nልብሶችን O\nለማድረቅ O\nእና O\nለመስቀል O\nተስማሚ O\nየሆነ O\nዋጋ B-PRICE\n3400 I-PRICE\nብር I-PRICE\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 695           የልብስ O\nማስጫ O\nማድረቂያ O\n3 I-PRICE\nእስከ O\n40 I-PRICE\nመሸከም O\nሚችል O\nማጠፍ O\nመዘርጋት O\nሚቻል O\nቦታ O\nቆጣቢ O\nለ O\nልብስን O\nበፍጥነት O\nየሚያደርቅ O\nበቤት O\nውስጥም O\nሆነ O\nከቤት O\nውጭ O\nልብሶችን O\nለማድረቅ O\nእና O\nለመስቀል O\nተስማሚ O\nየሆነ O\nዋጋ B-PRICE\n3400 I-PRICE\nብር I-PRICE\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 696                                                                                                                                                                                                                          የጡት O\nጫፍ O\nዋጋ B-PRICE\n400 I-PRICE\nብር I-PRICE\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O
# 697                                                                                                            ልብስ O\nመተኮሻ O\n2200 I-PRICE\nልብስ O\nየማያቃጥል O\nበእፏሎት O\nየሚሰራ O\nለሁሉም O\nየጨርቅ O\nአይነቶች O\nየሚሆን O\nዋጋ B-PRICE\n2500 I-PRICE\nብር I-PRICE\nውስን O\nፍሬ O\nነው O\nያለው O\nአድራሻ O\nመገናኛ B-LOC\nመሰረት I-LOC\nደፋር I-LOC\nሞል I-LOC\nሁለተኛ O\nፎቅ O\nቢሮ O\nቁ O\nፒያሳ B-LOC\nጊዮርጊስ I-LOC\nአደባባይ I-LOC\nራመት I-LOC\nታቦር I-LOC\nኦዳ I-LOC\nህንፃ I-LOC\n1ኛ O\nፎቅ O\nሱቅ O\nቁ O\n1 I-PRICE\nፒያሳ B-LOC\nቅርንጫፍ O\nበ O\nለማዘዝ O\nይጠቀሙ O\nለተጨማሪ O\nማብራሪያ O\nየቴሌግራም O\nገፃችን O

# %% [markdown]
# ###Save in CoNLL format

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = 'labeled_telegram_product_price_location.conll'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in dft.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")

# %% [markdown]
# ### Tokenizer

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
tokenizer = AutoTokenizer.from_pretrained("masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0")
model = AutoModelForTokenClassification.from_pretrained("masakhane/afroxlmr-large-ner-masakhaner-1.0_2.0")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = df['Message'][10]
ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-LOC', 'score': 0.77822363, 'index': 43, 'word': '▁ስ', 'start': 117, 'end': 118}, {'entity': 'I-LOC', 'score': 0.58282, 'index': 44, 'word': 'ሪ', 'start': 118, 'end': 119}, {'entity': 'I-LOC', 'score': 0.8872894, 'index': 45, 'word': '▁', 'start': 120, 'end': 121}, {'entity': 'I-LOC', 'score': 0.7864612, 'index': 46, 'word': 'ኤም', 'start': 120, 'end': 122}, {'entity': 'I-LOC', 'score': 0.8502413, 'index': 47, 'word': '▁ሲ', 'start': 123, 'end': 124}, {'entity': 'I-LOC', 'score': 0.5737138, 'index': 48, 'word': 'ቲ', 'start': 124, 'end': 125}, {'entity': 'I-LOC', 'score': 0.5543835, 'index': 49, 'word': '▁ሞ', 'start': 126, 'end': 127}, {'entity': 'I-LOC', 'score': 0.8828338, 'index': 50, 'word': 'ል', 'start': 127, 'end': 128}, {'entity': 'I-LOC', 'score': 0.76899004, 'index': 51, 'word': '▁', 'start': 130, 'end': 131}, {'entity': 'I-LOC', 'score': 0.5774763, 'index': 52, 'word': 'ሁለተኛ', 'start': 130, 'end': 134}, {'entity': 'B-LOC', 'score': 0.9574409, 'index': 64, 'word': '▁ሊ', 'start': 153, 'end': 154}, {'entity': 'I-LOC', 'score': 0.9331774, 'index': 65, 'word': 'ፍ', 'start': 154, 'end': 155}, {'entity': 'I-LOC', 'score': 0.98846066, 'index': 66, 'word': 'ቱ', 'start': 155, 'end': 156}, {'entity': 'I-LOC', 'score': 0.545, 'index': 67, 'word': '▁ፊት', 'start': 157, 'end': 159}, {'entity': 'I-ORG', 'score': 0.5013846, 'index': 80, 'word': '▁መ', 'start': 177, 'end': 178}, {'entity': 'I-ORG', 'score': 0.915992, 'index': 81, 'word': 'ዳ', 'start': 178, 'end': 179}, {'entity': 'I-ORG', 'score': 0.94669986, 'index': 82, 'word': 'ህ', 'start': 179, 'end': 180}, {'entity': 'I-ORG', 'score': 0.9730055, 'index': 83, 'word': 'ኒ', 'start': 180, 'end': 181}, {'entity': 'I-ORG', 'score': 0.96530104, 'index': 84, 'word': 'ዓለም', 'start': 181, 'end': 184}, {'entity': 'I-ORG', 'score': 0.962767, 'index': 85, 'word': '▁ቤተ', 'start': 185, 'end': 187}, {'entity': 'I-ORG', 'score': 0.8680226, 'index': 86, 'word': '/', 'start': 187, 'end': 188}, {'entity': 'I-ORG', 'score': 0.9250933, 'index': 87, 'word': 'ክር', 'start': 188, 'end': 190}, {'entity': 'I-ORG', 'score': 0.9565316, 'index': 88, 'word': 'ስቲ', 'start': 190, 'end': 192}, {'entity': 'I-ORG', 'score': 0.8840065, 'index': 89, 'word': 'ያን', 'start': 192, 'end': 194}, {'entity': 'B-LOC', 'score': 0.91544473, 'index': 93, 'word': '▁#', 'start': 203, 'end': 204}, {'entity': 'I-LOC', 'score': 0.7474842, 'index': 94, 'word': 'ዛ', 'start': 204, 'end': 205}, {'entity': 'I-LOC', 'score': 0.9778991, 'index': 95, 'word': 'ም', 'start': 205, 'end': 206}, {'entity': 'I-LOC', 'score': 0.9826668, 'index': 96, 'word': '_', 'start': 206, 'end': 207}, {'entity': 'I-LOC', 'score': 0.992358, 'index': 97, 'word': 'ሞ', 'start': 207, 'end': 208}, {'entity': 'I-LOC', 'score': 0.9859561, 'index': 98, 'word': 'ል', 'start': 208, 'end': 209}, {'entity': 'I-LOC', 'score': 0.9195112, 'index': 99, 'word': '▁2', 'start': 210, 'end': 211}, {'entity': 'B-ORG', 'score': 0.89675534, 'index': 144, 'word': '▁በ', 'start': 304, 'end': 305}, {'entity': 'I-ORG', 'score': 0.4993732, 'index': 146, 'word': 'gram', 'start': 309, 'end': 313}]

# %%
df.to_csv('telegram_data.csv', index=False)

# %%
df.to_csv('labeled_data.csv')
